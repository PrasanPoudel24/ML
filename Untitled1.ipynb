# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import StackingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X=df.drop('species',axis=1)
Y=df['species']

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(Y)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)

# %%
base_learners=[
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('svc',SVC(probability=True, kernel='rbf',random_state=42)),
    ('lr,',LogisticRegression(max_iter=1000))
]

# %%
meta_learner= LogisticRegression(max_iter=1000)

# %%
stacking_clf= StackingClassifier(
    estimators=base_learners,
    final_estimator=meta_learner,
    cv=5
)

# %%
stacking_clf.fit(X_train,Y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('dt', DecisionTreeClassifier(random_state=42)),
#                                ('svc', SVC(probability=True, random_state=42)),
#                                ('lr,', LogisticRegression(max_iter=1000))],
#                    final_estimator=LogisticRegression(max_iter=1000))

# %%
y_pred=stacking_clf.predict(X_test)

# %%
accuracy=accuracy_score(Y_test,y_pred)

# %%
accuracy
# Out:
# 0.9666666666666667

# %% [markdown]
# # using random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier(
    n_estimators=100, #numbers of trees
    max_depth=None, # let tree grow fully
    random_state=42
)

# %%
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_predict=rf_model.predict(X_test)

# %%
accuracy=accuracy_score(Y_test,y_predict)

# %%
accuracy
# Out:
# 0.9

# %% [markdown]
# # ada boost

# %%
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
ada_model=AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
ada_model.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=42)

# %%
y_predictor=ada_model.predict(X_test)

# %%
accuracy=accuracy_score(Y_test,y_predictor)

# %%
accuracy
# Out:
# 0.9333333333333333

# %%
gd_model = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1,random_state=42)

# %%
gd_model.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_predictor=gd_model.predict(X_test)

# %%
accuracy=accuracy_score(Y_test,y_predictor)

# %%
accuracy
# Out:
# 0.9666666666666667

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42
)

print(xgb_model)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 from xgboost import XGBClassifier
#       3 xgb_model = XGBClassifier(
#       4     n_estimators=100,
#       5     learning_rate=0.1,
#    (...)
#       9     random_state=42
#      10 )
#      12 print(xgb_model)
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
xgb_model= XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, use_lable_encoder=False, eval_metric='mlogloss', random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 xgb_model= XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, use_lable_encoder=False, eval_metric='mlogloss', random_state=42)
#
# NameError: name 'XGBClassifier' is not defined
